# %% [markdown]
# ## 4-2 서울시 구별 주유소 가격 정보 얻기

# %%
from selenium import webdriver

# %%
import platform
path="c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

if platform.system() == "Darwin":
    rc('font', family='AppleGothic')
    driver = webdriver.Chrome('./driver/chromedriver')
elif platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    
    rc('font', family=font_name)
    options = Options()
    options.add_argument('--no-sandbox')    
    #driver = webdriver.Chrome('./driver/chromedriver.exe')
    driver = webdriver.Chrome(chrome_options=options, executable_path=r"./driver/chromedriver.exe")
 
else:
    print('Unknown system... sorry')

# %%
driver.get("http://www.opinet.co.kr/searRgSelect.do")

# %%
gu_list_raw = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
gu_list = gu_list_raw.find_elements_by_tag_name("option")

# %%
gu_names = [option.get_attribute("value") for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
element = driver.find_element_by_id("SIGUNGU_NM0")
element.send_keys(gu_names[0])

# %%
xpath = """//*[@id="searRgSelect"]"""
element_sel_gu = driver.find_element_by_xpath(xpath).click()

# %%
xpath = """//*[@id="glopopd_excel"]"""
element_sel_excel = driver.find_element_by_xpath(xpath).click()

# %%
import time
from tqdm import tqdm_notebook

for gu in tqdm_notebook(gu_names):
    element = driver.find_element_by_id("SIGUNGU_NM0")
    element.send_keys(gu)
    
    time.sleep(2)
   
    xpath = """//*[@id="searRgSelect"]"""
    element_sel_gu = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
    
    xpath = """//*[@id="glopopd_excel"]"""
    element_sel_excel = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))

# %%
driver.close()

# %%
import pandas as pd
from glob import glob

# %%
glob('./data/지역*.xls')
# Out:
# ['./data/지역_위치별(주유소) (9).xls',
#  './data/지역_위치별(주유소) (12).xls',
#  './data/지역_위치별(주유소) (5).xls',
#  './data/지역_위치별(주유소) (24).xls',
#  './data/지역_위치별(주유소) (25).xls',
#  './data/지역_위치별(주유소) (4).xls',
#  './data/지역_위치별(주유소) (13).xls',
#  './data/지역_위치별(주유소) (8).xls',
#  './data/지역_위치별(주유소) (3).xls',
#  './data/지역_위치별(주유소) (18).xls',
#  './data/지역_위치별(주유소) (22).xls',
#  './data/지역_위치별(주유소) (14).xls',
#  './data/지역_위치별(주유소) (15).xls',
#  './data/지역_위치별(주유소) (23).xls',
#  './data/지역_위치별(주유소) (19).xls',
#  './data/지역_위치별(주유소) (2).xls',
#  './data/지역_위치별(주유소) (20).xls',
#  './data/지역_위치별(주유소) (1).xls',
#  './data/지역_위치별(주유소) (16).xls',
#  './data/지역_위치별(주유소) (17).xls',
#  './data/지역_위치별(주유소) (21).xls',
#  './data/지역_위치별(주유소) (10).xls',
#  './data/지역_위치별(주유소).xls',
#  './data/지역_위치별(주유소) (7).xls',
#  './data/지역_위치별(주유소) (6).xls',
#  './data/지역_위치별(주유소) (11).xls']

# %%
stations_files =glob('./data/지역*.xls')
stations_files
# Out:
# ['./data/지역_위치별(주유소) (9).xls',
#  './data/지역_위치별(주유소) (12).xls',
#  './data/지역_위치별(주유소) (5).xls',
#  './data/지역_위치별(주유소) (24).xls',
#  './data/지역_위치별(주유소) (25).xls',
#  './data/지역_위치별(주유소) (4).xls',
#  './data/지역_위치별(주유소) (13).xls',
#  './data/지역_위치별(주유소) (8).xls',
#  './data/지역_위치별(주유소) (3).xls',
#  './data/지역_위치별(주유소) (18).xls',
#  './data/지역_위치별(주유소) (22).xls',
#  './data/지역_위치별(주유소) (14).xls',
#  './data/지역_위치별(주유소) (15).xls',
#  './data/지역_위치별(주유소) (23).xls',
#  './data/지역_위치별(주유소) (19).xls',
#  './data/지역_위치별(주유소) (2).xls',
#  './data/지역_위치별(주유소) (20).xls',
#  './data/지역_위치별(주유소) (1).xls',
#  './data/지역_위치별(주유소) (16).xls',
#  './data/지역_위치별(주유소) (17).xls',
#  './data/지역_위치별(주유소) (21).xls',
#  './data/지역_위치별(주유소) (10).xls',
#  './data/지역_위치별(주유소).xls',
#  './data/지역_위치별(주유소) (7).xls',
#  './data/지역_위치별(주유소) (6).xls',
#  './data/지역_위치별(주유소) (11).xls']

# %%
tmp_raw = []

for file_name in stations_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)

    station_raw = pd.concat(tmp_raw)

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 565 entries, 0 to 21
# Data columns (total 10 columns):
# 지역       565 non-null object
# 상호       565 non-null object
# 주소       565 non-null object
# 상표       565 non-null object
# 전화번호     565 non-null object
# 셀프여부     565 non-null object
# 고급휘발유    565 non-null object
# 휘발유      565 non-null object
# 경유       565 non-null object
# 실내등유     565 non-null object
# dtypes: object(10)
# memory usage: 48.6+ KB

# %%
station_raw.head()
# Out:
#       지역       상호                             주소     상표         전화번호 셀프여부  \
# 0  서울특별시    월계주유소           서울 노원구 월계로 252 (월계동)  GS칼텍스  02-917-7650    Y
# 1  서울특별시    삼육주유소       서울특별시 노원구  화랑로 822 (공릉동)  SK에너지  02-949-3677    Y
# 2  서울특별시    신성주유소           서울 노원구 월계로 328 (월계동)  S-OIL  02-916-4334    Y
# 3  서울특별시   화랑대주유소  서울특별시 노원구  화랑로483 (공릉동)화랑대주유소  SK에너지  02-972-5189    Y
# 4  서울특별시  태릉솔밭주유소         서울특별시 노원구 노원로 49 (공릉동)  S-OIL  02-976-5189    Y
#
#   고급휘발유   휘발유    경유  실내등유
# 0     -  1598  1398  1199
# 1     -  1615  1415  1000
# 2     -  1616  1416     -
# 3  1797  1617  1417  1050
# 4  1767  1617  1417     -

# %%
stations = pd.DataFrame({'Oil_store':station_raw['상호'],
                               '주소':station_raw['주소'],
                               '가격':station_raw['휘발유'],
                               '셀프':station_raw['셀프여부'],
                               '상표':station_raw['상표']})
stations.head()
# Out:
#   Oil_store    가격     상표 셀프                             주소
# 0     월계주유소  1598  GS칼텍스  Y           서울 노원구 월계로 252 (월계동)
# 1     삼육주유소  1615  SK에너지  Y       서울특별시 노원구  화랑로 822 (공릉동)
# 2     신성주유소  1616  S-OIL  Y           서울 노원구 월계로 328 (월계동)
# 3    화랑대주유소  1617  SK에너지  Y  서울특별시 노원구  화랑로483 (공릉동)화랑대주유소
# 4   태릉솔밭주유소  1617  S-OIL  Y         서울특별시 노원구 노원로 49 (공릉동)

# %%
stations['구'] = [eachAddress.split()[1] for eachAddress in stations['주소']]
stations.head()
# Out:
#   Oil_store    가격     상표 셀프                             주소    구
# 0     월계주유소  1598  GS칼텍스  Y           서울 노원구 월계로 252 (월계동)  노원구
# 1     삼육주유소  1615  SK에너지  Y       서울특별시 노원구  화랑로 822 (공릉동)  노원구
# 2     신성주유소  1616  S-OIL  Y           서울 노원구 월계로 328 (월계동)  노원구
# 3    화랑대주유소  1617  SK에너지  Y  서울특별시 노원구  화랑로483 (공릉동)화랑대주유소  노원구
# 4   태릉솔밭주유소  1617  S-OIL  Y         서울특별시 노원구 노원로 49 (공릉동)  노원구

# %%
stations['구'].unique()
# Out:
# array(['노원구', '동작구', '관악구', '중구', '중랑구', '강서구', '마포구', '금천구', '강북구',
#        '송파구', '은평구', '서대문구', '서초구', '종로구', '양천구', '강동구', '영등포구', '강남구',
#        '성동구', '서울특별시', '성북구', '용산구', '도봉구', '특별시', '구로구', '광진구', '동대문구'],
#       dtype=object)

# %%
stations[stations['구']=='서울특별시']
# Out:
#          Oil_store    가격     상표 셀프                           주소      구
# 13  SK네트웍스(주)효진주유소  1769  SK에너지  N  1 서울특별시 성동구 동일로 129 (성수동2가)  서울특별시

# %%
stations.loc[stations['구']=='서울특별시', '구'] = '성동구'
stations['구'].unique()
# Out:
# array(['노원구', '동작구', '관악구', '중구', '중랑구', '강서구', '마포구', '금천구', '강북구',
#        '송파구', '은평구', '서대문구', '서초구', '종로구', '양천구', '강동구', '영등포구', '강남구',
#        '성동구', '성북구', '용산구', '도봉구', '특별시', '구로구', '광진구', '동대문구'],
#       dtype=object)

# %%
stations[stations['구']=='특별시']
# Out:
#    Oil_store    가격     상표 셀프                        주소    구
# 10     서현주유소  1599  S-OIL  Y  서울 특별시 도봉구 방학로 142 (방학동)  특별시

# %%
stations.loc[stations['구']=='특별시', '구'] = '도봉구'
stations['구'].unique()
# Out:
# array(['노원구', '동작구', '관악구', '중구', '중랑구', '강서구', '마포구', '금천구', '강북구',
#        '송파구', '은평구', '서대문구', '서초구', '종로구', '양천구', '강동구', '영등포구', '강남구',
#        '성동구', '성북구', '용산구', '도봉구', '구로구', '광진구', '동대문구'], dtype=object)

# %%
stations[stations['가격']=='-']
# Out:
#             Oil_store 가격      상표 셀프                          주소     구
# 17        유성주유소(self)  -  현대오일뱅크  Y        서울 중랑구 망우로 436 (망우동)   중랑구
# 34            하이웨이주유소  -   S-OIL  N       서울 강서구 공항대로 432 (화곡동)   강서구
# 13              서강주유소  -   SK에너지  N        서울 마포구 독막로 134 (창전동)   마포구
# 12              새한주유소  -   SK에너지  Y     서울특별시 강북구  도봉로 75 (미아동)   강북구
# 24              목동주유소  -   S-OIL  N       서울 양천구 목동중앙로 125 (목동)   양천구
# 25              현대주유소  -   S-OIL  Y      서울 양천구 남부순환로 372 (신월동)   양천구
# 17      명진석유(주)동서울주유소  -   GS칼텍스  Y  서울특별시 강동구  천호대로 1456 (상일동)   강동구
# 33              하나주유소  -   S-OIL  N   서울특별시 영등포구  도림로 236 (신길동)  영등포구
# 34              대지주유소  -   SK에너지  N    서울 영등포구 영등포로 115 (당산동2가)  영등포구
# 21  현대오일뱅크(주)직영신구로주유소  -  현대오일뱅크  N   서울특별시 구로구  가마산로 293 (구로동)   구로구

# %%
stations = stations[stations['가격'] != '-']
stations.head()
# Out:
#   Oil_store    가격     상표 셀프                             주소    구
# 0     월계주유소  1598  GS칼텍스  Y           서울 노원구 월계로 252 (월계동)  노원구
# 1     삼육주유소  1615  SK에너지  Y       서울특별시 노원구  화랑로 822 (공릉동)  노원구
# 2     신성주유소  1616  S-OIL  Y           서울 노원구 월계로 328 (월계동)  노원구
# 3    화랑대주유소  1617  SK에너지  Y  서울특별시 노원구  화랑로483 (공릉동)화랑대주유소  노원구
# 4   태릉솔밭주유소  1617  S-OIL  Y         서울특별시 노원구 노원로 49 (공릉동)  노원구

# %%
stations['가격'] = [float(value) for value in stations['가격']]

# %%
stations.reset_index(inplace=True)
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 6 columns):
# Oil_store    555 non-null object
# 가격           555 non-null float64
# 상표           555 non-null object
# 셀프           555 non-null object
# 주소           555 non-null object
# 구            555 non-null object
# dtypes: float64(1), object(5)
# memory usage: 26.1+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

stations.boxplot(column='가격', by='셀프', figsize=(12,8))

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='가격', hue='셀프', data=stations, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='가격', hue='셀프', data=stations, palette="Set3")
sns.swarmplot(x='상표', y='가격', data=stations, color=".6")
plt.show()

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
stations.sort_values(by="가격", ascending=False).head(100)
# Out:
#               Oil_store      가격      상표 셀프                            주소     구
# 56                서남주유소  2299.0   SK에너지  N          서울 중구 통일로 30 (봉래동1가)    중구
# 55                장충주유소  2277.0   SK에너지  N        서울 중구 장충단로 202 (장충동1가)    중구
# 251               양재주유소  2276.0   SK에너지  N         서울 서초구 바우뫼로 178 (양재동)   서초구
# 376             뉴서울(강남)  2240.0   SK에너지  N          서울 강남구 언주로 716 (논현동)   강남구
# 493             뉴서울(강남)  2240.0   SK에너지  N          서울 강남구 언주로 716 (논현동)   강남구
# 417               삼선주유소  2185.0   S-OIL  N   서울특별시 성북구  창경궁로 324 (삼선동1가)   성북구
# 54                약수주유소  2176.0   GS칼텍스  N           서울 중구 다산로 173 (신당동)    중구
# 53       주)중앙에너비스 퇴계로지점  2168.0   SK에너지  N      서울특별시 중구  퇴계로 228 (필동2가)    중구
# 401             (주)성북주유소  1607.0  현대오일뱅크  N      서울 성북구 보문로 142 (보문동1가)   성북구
# 147                상아주유소  1607.0  현대오일뱅크  Y         서울 송파구 거마로 82 (마천동)   송파구
# 146                삼화주유소  1607.0   GS칼텍스  Y  서울특별시 송파구  백제고분로 125 (잠실동)   송파구
# 378                정호주유소  1608.0    자가상표  N       서울 성동구 고산자로 307 (마장동)   성동구
#
# [100 rows x 6 columns]

# %%
import numpy as np
gu_data = pd.pivot_table(stations, index=["구"], values=["가격"], aggfunc=np.mean)
gu_data.sort_values(by="가격", ascending=False).head(25)
# Out:
#                가격
# 구
# 중구    2059.166667
# 용산구   1994.133333
# 종로구   1956.555556
# 강남구   1838.119048
# 마포구   1792.615385
# 서초구   1725.292683
# 성동구   1715.666667
# 강동구   1704.823529
# 영등포구  1697.727273
# 송파구   1673.709677
# 노원구   1669.750000
# 서대문구  1669.625000
# 구로구   1668.857143
# 양천구   1668.208333
# 동대문구  1663.045455
# 강서구   1657.147059
# 관악구   1656.777778
# 성북구   1650.086957
# 광진구   1639.444444
# 동작구   1636.454545
# 도봉구   1627.210526
# 은평구   1626.111111
# 중랑구   1620.411765
# 금천구   1618.000000
# 강북구   1600.916667

# %%
geo_path = './data/02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, tiles='Stamen Toner')
map.choropleth(geo_data = geo_str,
               data = gu_data,
               columns = [gu_data.index, '가격'],
               fill_color='PuRd',
               key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oil_price_top10 = stations.sort_values(by='가격', ascending=False).head(10)
oil_price_top10
# Out:
#           Oil_store      가격     상표 셀프                           주소    구
# 56            서남주유소  2299.0  SK에너지  N         서울 중구 통일로 30 (봉래동1가)   중구
# 55            장충주유소  2277.0  SK에너지  N       서울 중구 장충단로 202 (장충동1가)   중구
# 251           양재주유소  2276.0  SK에너지  N        서울 서초구 바우뫼로 178 (양재동)  서초구
# 376         뉴서울(강남)  2240.0  SK에너지  N         서울 강남구 언주로 716 (논현동)  강남구
# 493         뉴서울(강남)  2240.0  SK에너지  N         서울 강남구 언주로 716 (논현동)  강남구
# 417           삼선주유소  2185.0  S-OIL  N  서울특별시 성북구  창경궁로 324 (삼선동1가)  성북구
# 54            약수주유소  2176.0  GS칼텍스  N          서울 중구 다산로 173 (신당동)   중구
# 53   주)중앙에너비스 퇴계로지점  2168.0  SK에너지  N     서울특별시 중구  퇴계로 228 (필동2가)   중구
# 259  (주)중앙에너비스혜화주유소  2168.0  SK에너지  N       서울 종로구 창경궁로35길 1 (혜화동)  종로구
# 260        (주)대양씨앤씨  2168.0  GS칼텍스  N          서울 종로구 사직로 65 (사직동)  종로구

# %%
oil_price_bottom10 = stations.sort_values(by='가격', ascending=True).head(10)
oil_price_bottom10
# Out:
#              Oil_store      가격      상표 셀프                        주소    구
# 134           북서울고속주유소  1557.0   S-OIL  Y   서울특별시 강북구 삼양로 410 (수유동)  강북구
# 74           강서오곡셀프주유소  1563.0   SK에너지  Y   서울특별시 강서구 벌말로 254 (오곡동)  강서구
# 135             수유동주유소  1566.0   GS칼텍스  Y  서울특별시 강북구  도봉로 395 (수유동)  강북구
# 433    도봉제일주유소(주)송만에너지  1567.0  현대오일뱅크  N  서울특별시 도봉구  도봉로 783 (도봉동)  도봉구
# 434   한이에너지(주)KLP제1주유소  1567.0  현대오일뱅크  N   서울특별시 도봉구  도봉로 596 (창동)  도봉구
# 177  (주)명연에너지 수색훼미리주유소  1567.0  현대오일뱅크  Y      서울 은평구 수색로 236 (수색동)  은평구
# 179             타이거주유소  1569.0   SK에너지  Y      서울 은평구 수색로 188 (증산동)  은평구
# 178              수색뉴타운  1569.0   GS칼텍스  Y  서울특별시 은평구  수색로 350 (수색동)  은평구
# 438   SK네트웍스(주)도봉행복주유소  1569.0   SK에너지  Y  서울특별시 도봉구  도봉로 941 (도봉동)  도봉구
# 436              쌍문주유소  1569.0   S-OIL  Y  서울특별시 도봉구  도봉로 547 (쌍문동)  도봉구

# %%
gmap_key ="AIzaSyAyF0WcjPtq3hJok253OUWvX8qRiWXrDIU"
gmaps = googlemaps.Client(key=gmap_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        print(tmp_add)
        tmp_map = gmaps.geocode(tmp_add)
        
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 서울 중구 통일로 30
# 서울 중구 장충단로 202
# 서울 서초구 바우뫼로 178
# 서울 강남구 언주로 716
# 서울 강남구 언주로 716
# 서울특별시 성북구  창경궁로 324
# 서울 중구 다산로 173
# 서울특별시 중구  퇴계로 228
# 서울 종로구 창경궁로35길 1
# 서울 종로구 사직로 65
#           Oil_store      가격     상표 셀프                           주소    구  \
# 56            서남주유소  2299.0  SK에너지  N         서울 중구 통일로 30 (봉래동1가)   중구
# 55            장충주유소  2277.0  SK에너지  N       서울 중구 장충단로 202 (장충동1가)   중구
# 251           양재주유소  2276.0  SK에너지  N        서울 서초구 바우뫼로 178 (양재동)  서초구
# 376         뉴서울(강남)  2240.0  SK에너지  N         서울 강남구 언주로 716 (논현동)  강남구
# 493         뉴서울(강남)  2240.0  SK에너지  N         서울 강남구 언주로 716 (논현동)  강남구
# 417           삼선주유소  2185.0  S-OIL  N  서울특별시 성북구  창경궁로 324 (삼선동1가)  성북구
# 54            약수주유소  2176.0  GS칼텍스  N          서울 중구 다산로 173 (신당동)   중구
# 53   주)중앙에너비스 퇴계로지점  2168.0  SK에너지  N     서울특별시 중구  퇴계로 228 (필동2가)   중구
# 259  (주)중앙에너비스혜화주유소  2168.0  SK에너지  N       서울 종로구 창경궁로35길 1 (혜화동)  종로구
# 260        (주)대양씨앤씨  2168.0  GS칼텍스  N          서울 종로구 사직로 65 (사직동)  종로구
#
#            lat         lng
# 56   37.558348  126.972090
# 55   37.562719  127.007010
# 251  37.478071  127.039610
# 376  37.517636  127.035756
# 493  37.517636  127.035756
# 417  37.587908  127.005575
# 54   37.559009  127.012663
# 53   37.561648  126.997142
# 259  37.586068  127.001058
# 260  37.574464  126.966618

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_bottom10.index):
    try:
        tmp_add = str(oil_price_bottom10['주소'][n]).split('(')[0]
        print(tmp_add)
        tmp_map = gmaps.geocode(tmp_add)
        
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 서울특별시 강북구 삼양로 410
# 서울특별시 강서구 벌말로 254
# 서울특별시 강북구  도봉로 395
# 서울특별시 도봉구  도봉로 783
# 서울특별시 도봉구  도봉로 596
# 서울 은평구 수색로 236
# 서울 은평구 수색로 188
# 서울특별시 은평구  수색로 350
# 서울특별시 도봉구  도봉로 941
# 서울특별시 도봉구  도봉로 547
#              Oil_store      가격      상표 셀프                        주소    구  \
# 134           북서울고속주유소  1557.0   S-OIL  Y   서울특별시 강북구 삼양로 410 (수유동)  강북구
# 74           강서오곡셀프주유소  1563.0   SK에너지  Y   서울특별시 강서구 벌말로 254 (오곡동)  강서구
# 135             수유동주유소  1566.0   GS칼텍스  Y  서울특별시 강북구  도봉로 395 (수유동)  강북구
# 433    도봉제일주유소(주)송만에너지  1567.0  현대오일뱅크  N  서울특별시 도봉구  도봉로 783 (도봉동)  도봉구
# 434   한이에너지(주)KLP제1주유소  1567.0  현대오일뱅크  N   서울특별시 도봉구  도봉로 596 (창동)  도봉구
# 177  (주)명연에너지 수색훼미리주유소  1567.0  현대오일뱅크  Y      서울 은평구 수색로 236 (수색동)  은평구
# 179             타이거주유소  1569.0   SK에너지  Y      서울 은평구 수색로 188 (증산동)  은평구
# 178              수색뉴타운  1569.0   GS칼텍스  Y  서울특별시 은평구  수색로 350 (수색동)  은평구
# 438   SK네트웍스(주)도봉행복주유소  1569.0   SK에너지  Y  서울특별시 도봉구  도봉로 941 (도봉동)  도봉구
# 436              쌍문주유소  1569.0   S-OIL  Y  서울특별시 도봉구  도봉로 547 (쌍문동)  도봉구
#
#             lng        lat
# 134  127.017203  37.640155
# 74   126.768567  37.555284
# 135  127.029568  37.642140
# 433  127.044051  37.674434
# 434  127.040569  37.657714
# 177  126.897774  37.581122
# 179  126.902050  37.578424
# 178  126.887542  37.587107
# 438  127.045313  37.688335
# 436  127.037515  37.653949

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]],
                            radius=15, color='#CD3181',
                            fill_color='#CD3181').add_to(map)
        
for n in oil_price_bottom10.index:
    if pd.notnull(oil_price_bottom10['lat'][n]):
        folium.CircleMarker([oil_price_bottom10['lat'][n], 
                             oil_price_bottom10['lng'][n]],
                             radius=15, color='#3186cc',
                             fill_color='#3186cc').add_to(map)
        
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
